# %% [markdown]
# <a href="https://colab.research.google.com/github/spadao/tensorflow-deep-learning/blob/Updates/01_neural_network_regression_in_tensorflow_edit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
